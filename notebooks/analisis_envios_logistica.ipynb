# %% [markdown]
# Lectura del archivo y normalizacion del archivo y lecutra de los modulos de la automatizacion

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os
import pandas as pd
from pathlib import Path
import plotly.express as px



# Detectar raíz del proyecto (subiendo desde el cwd)
project_root = Path(os.getcwd()).resolve().parent  # sube un nivel desde notebooks/
sys.path.append(str(project_root))

# Ruta hacia el módulo src/
src_path = project_root / "src"
if str(src_path) not in sys.path:
    sys.path.append(str(src_path))

# Importar módulos desde src/
from src.data_loading import (
    cargar_datos_excel
)
from src.data_cleaning import (
    estandarizar_columnas,
    convertir_fechas,
)
from src.logistica import (
    calcular_tiempo_entrega,    
)
from src.data_cleaning import (
    limpiar_metodo_envio
)
from src.exportacion import (
    exportar_excel,
)

# %%
ruta_excel = "../data/raw/Sales report completa.xlsx" 
df = (
    cargar_datos_excel(ruta_excel, sheet_name="Ventas Supermercado")
    .pipe(estandarizar_columnas)
    .pipe(convertir_fechas)
    .pipe(calcular_tiempo_entrega)
    .pipe(limpiar_metodo_envio)
)

# %% [markdown]
# visualizacion de las columnas utilizando jupyter

# %%
pd.DataFrame(df.columns, columns=['Columnas'])
# Out:
#            Columnas
# 0      numero_venta
# 1        mes_salida
# 2        dia_salida
# 3        ano_salida
# 4       mes_entrega
# 5       dia_entrega
# 6       ano_entrega
# 7      metodo_envio
# 8    numero_cliente
# 9    nombre_cliente
# 10         segmento
# 11           ciudad
# 12           estado
# 13             pais
# 14      id_producto
# 15           ventas
# 16         cantidad
# 17        descuento
# 18         utilidad
# 19      costo_envio
# 20  prioridad_envio
# 21     fecha_salida
# 22    fecha_entrega
# 23   tiempo_entrega

# %% [markdown]
# medias estadisticas para analisis del tiempo de entrega

# %%
df['tiempo_entrega'].describe()
# Out:
# count    51290.000000
# mean         3.969370
# std          1.729437
# min          0.000000
# 25%          3.000000
# 50%          4.000000
# 75%          5.000000
# max          7.000000
# Name: tiempo_entrega, dtype: float64

# %% [markdown]
# inicio de analisis geografico

# %%
# Contar número de envíos por ciudad
top_ciudades = df.groupby(['pais', 'ciudad']).size().reset_index(name='num_envios')

# Ordenar de mayor a menor
top_ciudades = top_ciudades.sort_values(by='num_envios', ascending=False)

# Mostrar primeras filas
print(top_ciudades.head(20))
# Out:
#                     pais         ciudad  num_envios
# 3427       United States  New York City         915
# 3364       United States    Los Angeles         747
# 3472       United States   Philadelphia         537
# 3536       United States  San Francisco         510
# 915   Dominican Republic  Santo Domingo         443
# 2437         Philippines         Manila         432
# 3550       United States        Seattle         428
# 3305       United States        Houston         377
# 1561            Honduras    Tegucigalpa         362
# 1726           Indonesia        Jakarta         337
# 2331           Nicaragua        Managua         336
# 2360             Nigeria          Lagos         333
# 3178       United States        Chicago         314
# 2833              Turkey       Istanbul         314
# 2144              Mexico    Mexico City         300
# 2776            Thailand        Bangkok         287
# 124            Australia         Sydney         271
# 3028      United Kingdom         London         257
# 932                Egypt          Cairo         248
# 141              Austria         Vienna         245

# %%
# Tomar solo las 20 ciudades con más envíos
top5_ciudades = top_ciudades.head(20)

# %%
fig1 = px.bar(
    top5_ciudades,
    x='num_envios',
    y='ciudad',
    color='pais',
    orientation='h',
    title='Top 20 ciudades con más envíos',
    labels={'num_envios': 'Número de envíos', 'ciudad': 'Ciudad'}
)

fig1.update_layout(
    yaxis={'categoryorder': 'total ascending'},
    plot_bgcolor='white'
)

fig1.show()

# %%
import plotly.express as px

fig5 = px.box(
    df,
    x='metodo_envio',
    y='tiempo_entrega',
    color='metodo_envio',
    title='Duración del envío por Método de Envío',
    color_discrete_sequence=px.colors.qualitative.Set2
)

fig5.update_layout(
    xaxis_title='Método de Envío',
    yaxis_title='Tiempo de Entrega',
    boxmode='group'
)

fig5.show()

# %%
import plotly.express as px

fig3 = px.box(
    df,
    x='prioridad_envio',
    y='tiempo_entrega',
    color='prioridad_envio',
    title='Duración del envío por Prioridad de Envío',
    color_discrete_sequence=px.colors.qualitative.Set2
)

fig3.update_layout(
    xaxis_title='Prioridad de Envío',
    yaxis_title='Tiempo de Entrega',
    boxmode='group'
)

fig3.show()

# %%
fig4 = px.violin(
    df,
    x='prioridad_envio',
    y='tiempo_entrega',
    color='prioridad_envio',
    box=True,
    points='all',
    title='Distribución del tiempo de entrega por Prioridad de Envío',
    color_discrete_sequence=px.colors.qualitative.Set2
)

fig4.update_layout(
    xaxis_title='Prioridad de Envío',
    yaxis_title='Tiempo de Entrega'
)

fig4.show()

# %%
import pandas as pd

# 1️⃣ Crear rangos
df['rango_costo_envio'] = pd.cut(df['costo_envio'], bins=5)

# 2️⃣ Generar etiquetas personalizadas
df['rango_costo_envio_label'] = df['rango_costo_envio'].apply(
    lambda x: f"${int(x.left)} - ${int(x.right)} USD"
)

# Revisa un ejemplo
print(df[['costo_envio', 'rango_costo_envio', 'rango_costo_envio_label']].head())
# Out:
#    costo_envio  rango_costo_envio rango_costo_envio_label
# 0        35.46  (-0.934, 186.714]           $0 - $186 USD
# 1         9.72  (-0.934, 186.714]           $0 - $186 USD
# 2         8.17  (-0.934, 186.714]           $0 - $186 USD
# 3         4.82  (-0.934, 186.714]           $0 - $186 USD
# 4         4.70  (-0.934, 186.714]           $0 - $186 USD

# %%
import plotly.express as px

fig3 = px.box(
    df,
    x='rango_costo_envio_label',  # Usar la etiqueta
    y='tiempo_entrega',
    color='rango_costo_envio_label',
    title='Duración del envío por Rangos de Costo de Envío (USD)',
    color_discrete_sequence=px.colors.qualitative.Set2
)

fig3.update_layout(
    xaxis_title='Rango de Costo de Envío (USD)',
    yaxis_title='Tiempo de Entrega (días)',
    boxmode='group'
)

fig3.show()

# %%
import plotly.express as px

# Filtrar top 5 países con más envíos
top_paises = (
    df['pais']
    .value_counts()
    .nlargest(5)
    .index
)

df_top = df[df['pais'].isin(top_paises)].copy()

# Opcional: filtrar costos extremos
df_top = df_top[df_top['costo_envio'] < df_top['costo_envio'].quantile(0.95)]

# Scatter plot
fig8 = px.scatter(
    df_top,
    x='costo_envio',
    y='tiempo_entrega',
    color='pais',
    size='cantidad',  
    hover_data=['metodo_envio', 'prioridad_envio', 'ciudad'],
    title='Relación entre Costo de Envío, Tiempo de Entrega y Cantidades por País (TOP 5 Países)',
    color_discrete_sequence=px.colors.qualitative.Set2
)

fig8.update_layout(
    xaxis_title='Costo de Envío (USD)',
    yaxis_title='Tiempo de Entrega (días)',
)

fig8.show()

# %%
fig8.write_html("grafico.html")

# %%
import plotly.express as px

# Filtrar top 5 países
top_paises = (
    df['pais']
    .value_counts()
    .nlargest(5)
    .index
)

df_top = df[df['pais'].isin(top_paises)].copy()

# Opcional: filtrar outliers extremos de costo_envio
df_top = df_top[df_top['costo_envio'] < df_top['costo_envio'].quantile(0.95)]

# Scatter facetado
fig = px.scatter(
    df_top,
    x='costo_envio',
    y='tiempo_entrega',
    color='pais',
    size='cantidad',  # Opcional
    hover_data=['metodo_envio', 'prioridad_envio'],
    facet_col='pais',
    facet_col_wrap=3,  # Máx 3 columnas, se ajusta a tu pantalla
    title='Relación Costo de Envío vs Tiempo de Entrega - TOP 5 Países (Facet)',
    color_discrete_sequence=px.colors.qualitative.Set2
)

fig.update_layout(
    xaxis_title='Costo de Envío (USD)',
    yaxis_title='Tiempo de Entrega (días)',
)

fig.show()

# %%
pais_mayor = df.groupby('pais')['costo_envio'].mean().idxmax()
costo_max = df.groupby('pais')['costo_envio'].mean().max()

print(f"✅ El país con mayor costo de envío promedio es {pais_mayor} con ${costo_max:.2f} USD.")
# Out:
# ✅ El país con mayor costo de envío promedio es Taiwan con $155.66 USD.

# %%
df[['metodo_envio', 'prioridad_envio']].isnull().sum()
# Out:
# metodo_envio       0
# prioridad_envio    0
# dtype: int64
