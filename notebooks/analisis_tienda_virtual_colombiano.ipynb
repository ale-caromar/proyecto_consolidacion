# %% [markdown]
# Lectura del archivo

# %%
import pandas as pd
archivo = "../data/Tienda_Virtual_del_Estado_Colombiano_-_Consolidado_20250611.csv"
df = pd.read_csv(archivo)
df.head()
# Out:
#     Año Identificador de la Orden Rama de la Entidad Orden de la Entidad  \
# 0  2021                     82703        No Definido         No Definido
# 1  2018                     30520        No Definido         No Definido
# 2  2023                    113062        No Definido         No Definido
# 3  2024                    127825        No Definido         No Definido
# 4  2023                    120712        No Definido         No Definido
#
#   Sector de la Entidad                                            Entidad  \
# 0          No Definido  UNIDAD ADMINISTRATIVA ESPECIAL DE LA JUSTICIA ...
# 1          No Definido              EJERCITO NACIONAL - INTENDENCIA LOCAL
# 2          No Definido  DISTRITO ESPECIAL DE CIENCIA, TECNOLOGiA E INN...
# 3          No Definido                    TOLIMA - MUNICIPIO DE ALPUJARRA
# 4          No Definido  VALLE DEL CAUCA - PERSONERIA MUNICIPAL DE JAMUNDI
#
#                   Solicitante       Fecha Fecha vence  \
# ...

# %% [markdown]
# Contextualizacion del archivo

# %%
df.info()
df.describe(include='all', datetime_is_numeric=True)
df.columns
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145431 entries, 0 to 145430
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Año                            145431 non-null  int64
#  1   Identificador de la Orden      145431 non-null  object
#  2   Rama de la Entidad             145431 non-null  object
#  3   Orden de la Entidad            145431 non-null  object
#  4   Sector de la Entidad           145431 non-null  object
#  5   Entidad                        145431 non-null  object
#  6   Solicitante                    145431 non-null  object
#  7   Fecha                          145431 non-null  object
#  8   Fecha vence                    145431 non-null  object
#  9   Proveedor                      145431 non-null  object
#  10  Estado                         145431 non-null  object
#  11  Solicitud                      144325 non-null  float64
# ...

# %% [markdown]
# Top 5 solicitantes

# %%
df['Solicitante'].value_counts().head(5)
# Out:
# Solicitante
# SANDRA PATRICIA GRIMALDO ALVAREZ    456
# JUAN DAVID VELEZ BOLIVAR            422
# JORGE ALBEIRO CONTRERAS ROJAS       390
# JESuS ALBEIRO PEÑA ROA              360
# SONIA MARCELA PEDRAZA GONZALEZ      354
# Name: count, dtype: int64

# %%
df['Proveedor'].value_counts().head(5)
# Out:
# Proveedor
# PANAMERICANA LIBRERiA Y PAPELERiA S.A.        18446
# ORGANIZACIoN TERPEL S.A.                       5172
# COLOMBIANA DE COMERCIO S.A Y/O ALKOSTO S.A     4457
# CENCOSUD COLOMBIA S.A.                         3697
# PROVEER INSTITUCIONAL SAS                      2936
# Name: count, dtype: int64
